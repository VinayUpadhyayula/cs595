# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Parts of Speech Assessment

# %% [markdown]
# For this assessment we'll be using the short story [The Tale of Peter Rabbit](https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit) by Beatrix Potter (1902). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/14838.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

# %% [markdown]
# **1. Create a Doc object from the file `peterrabbit.txt`**<br>
# > HINT: Use `with open('../TextFiles/peterrabbit.txt') as f:`

# %%
with open('../TextFiles/peterrabbit.txt') as f:
    doc = nlp(f.read())

# %% [markdown]
# **2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.**

# %%
# Enter your code here:
for token in list(doc.sents)[2]:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}},{spacy.explain(token.tag_)}')
# Out:
# They       PRON     PRP   ,pronoun, personal
# lived      VERB     VBD   ,verb, past tense
# with       ADP      IN    ,conjunction, subordinating or preposition
# their      PRON     PRP$  ,pronoun, possessive
# Mother     NOUN     NN    ,noun, singular or mass
# in         ADP      IN    ,conjunction, subordinating or preposition
# a          DET      DT    ,determiner
# sand       NOUN     NN    ,noun, singular or mass
# -          PUNCT    HYPH  ,punctuation mark, hyphen
# bank       NOUN     NN    ,noun, singular or mass
# ,          PUNCT    ,     ,punctuation mark, comma
# underneath ADP      IN    ,conjunction, subordinating or preposition
# the        DET      DT    ,determiner
# root       NOUN     NN    ,noun, singular or mass
# of         ADP      IN    ,conjunction, subordinating or preposition
# a          DET      DT    ,determiner
#
#           SPACE    _SP   ,whitespace
# very       ADV      RB    ,adverb
# ...

# %% [markdown]
# **3. Provide a frequency list of POS tags from the entire document**

# %%
POS_counts = doc.count_by(spacy.attrs.POS)
for k,v in sorted(POS_counts.items()):
        print(f'{k}. {doc.vocab[k].text:{5}}: {v}')
# Out:
# 84. ADJ  : 53
# 85. ADP  : 125
# 86. ADV  : 63
# 87. AUX  : 49
# 89. CCONJ: 61
# 90. DET  : 90
# 92. NOUN : 172
# 93. NUM  : 9
# 94. PART : 28
# 95. PRON : 110
# 96. PROPN: 74
# 97. PUNCT: 171
# 98. SCONJ: 19
# 100. VERB : 135
# 103. SPACE: 99

# %% [markdown]
# **4. CHALLENGE: What percentage of tokens are nouns?**<br>
# HINT: the attribute ID for 'NOUN' is 91

# %%
print(POS_counts[92]/len(doc)*100)
# Out:
# 13.672496025437203

# %% [markdown]
# **5. Display the Dependency Parse for the third sentence**

# %%
#for entire doc 
displacy.render(doc, style='dep', jupyter=True, options={'distance': 110})
#for thrid sentence
displacy.render(list(doc.sents)[2], style='dep', jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="49dd4eb104464b55be291856a03eacfa-0" class="displacy" width="119290" height="577.0" direction="ltr" style="max-width: none; height: 577.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="487.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="487.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">Tale</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="487.0">
# ...

# %% [markdown]
# **6. Show the first two named entities from Beatrix Potter's *The Tale of Peter Rabbit* **

# %%
# print(doc.ents[0].text+' - '+doc.ents[0].label_+' - '+str(spacy.explain(doc.ents[0].label_)))
# print(doc.ents[1].text+' - '+doc.ents[1].label_+' - '+str(spacy.explain(doc.ents[1].label_)))
#more efficient way would be 
for i in range(0,2):
    print(doc.ents[i].text+' - '+doc.ents[i].label_+' - '+str(spacy.explain(doc.ents[i].label_)))
# Out:
# The Tale of Peter Rabbit - WORK_OF_ART - Titles of books, songs, etc.
# Beatrix Potter - PERSON - People, including fictional
# The Tale of Peter Rabbit - WORK_OF_ART - Titles of books, songs, etc.
# Beatrix Potter - PERSON - People, including fictional

# %% [markdown]
# **7. How many sentences are contained in *The Tale of Peter Rabbit*?**

# %%
len(list(doc.sents))
# Out:
# 55

# %% [markdown]
# **8. CHALLENGE: How many sentences contain named entities?**

# %%
named_ent_count = 0
for sent in list(doc.sents):
    if sent.ents:
        named_ent_count+=1
print(named_ent_count)
# Out:
# 35

# %% [markdown]
# **9. CHALLENGE: Display the named entity visualization for `list_of_sents[0]` from the previous problem**

# %%
displacy.render(list(doc.sents)[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
# ...

# %% [markdown]
# ### Great Job!
